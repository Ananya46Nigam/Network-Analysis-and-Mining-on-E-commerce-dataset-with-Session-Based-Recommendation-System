# %% [markdown]
# ## Importing the required modules

# %%
# !pip install stemming
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: stemming in /usr/local/lib/python3.10/dist-packages (1.0.1)

# %%
import string
import re
from nltk.corpus import stopwords
from stemming.porter2 import stem
import networkx 
from operator import itemgetter

# %% [markdown]
# ## Accessing the meta-data

# %%
Metadata_File = open('/content/amazon-meta.txt', 'r', encoding = 'utf-8')
Amazon_Products = {}

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import re
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

ps = PorterStemmer()
stopwords = set(stopwords.words("english"))
Amazon_Products = {}

def process_categories(categories):
    categories = re.compile('[%s]' % re.escape(string.digits + string.punctuation)).sub(' ', categories)
    categories = ' '.join(set(categories.lower().split()) - set(stopwords))
    categories = ' '.join(ps.stem(word) for word in categories.split())
    return categories

def add_metadata_to_products():
    global Amazon_Products
    with open('/content/amazon-meta.txt', 'r') as metadata_file:
      meta_data = {}
      for line in metadata_file:
        line = line.strip()

        if line.startswith('Id'):
            meta_data['Id'] = line[3:].strip()
        elif line.startswith('ASIN'):
            meta_data['ASIN'] = line[5:].strip()
        elif line.startswith('title'):
            meta_data['Title'] = ' '.join(line[6:].strip().split())
        elif line.startswith('group'):
            meta_data['Group'] = line[6:].strip()
        elif line.startswith('salesrank'):
            meta_data['SalesRank'] = int(line[10:].strip())
        elif line.startswith('similar'):
            meta_data['Copurchased'] = ' '.join(line.split()[2:])
        elif line.startswith('categories'):
            categories = ''
            num_categories = int(line.split()[1].strip())
            for i in range(num_categories):
                categories += metadata_file.readline().strip()
            meta_data['Categories'] = process_categories(categories)
        elif line.startswith('reviews'):
            total_reviews, avg_rating = 0, 0.0
            for review_line in metadata_file:
                review_line = review_line.strip()
                if not review_line:
                    break
                if review_line.startswith('total'):
                    total_reviews = int(review_line.split()[2].strip())
                    avg_rating = float(review_line.split()[7].strip())
            meta_data['TotalReviews'] = total_reviews
            meta_data['AvgRating'] = avg_rating

            # reset for next product
            Amazon_Products[meta_data['ASIN']] = meta_data
            meta_data = {}
add_metadata_to_products()

# %%
# Amazon_Products

# %%
# Amazon_Products.items()

# %% [markdown]
# ## Filtering out data related to book records

# %%
# Amazon_Books.keys()

# %%
Amazon_Books = {}
for asin, metadata in Amazon_Products.items():
    if (metadata['Group'] == 'Book'):
        Amazon_Books[asin] = Amazon_Products[asin]

# %%
for asin, metadata in Amazon_Books.items():
    Amazon_Books[asin]['Copurchased'] = ' '.join([cp for cp in metadata['Copurchased'].split() if cp in Amazon_Books.keys()])

# %%
Amazon_Books
# Out:
# {'0827229534': {'Id': '1',
#   'ASIN': '0827229534',
#   'Title': 'Patterns of Preaching: A Sermon Sampler',
#   'Group': 'Book',
#   'SalesRank': 396585,
#   'Copurchased': '0804215715 0687023955',
#   'Categories': 'religion sermon clergi book spiritu subject preach christian',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0738700797': {'Id': '2',
#   'ASIN': '0738700797',
#   'Title': 'Candlemas: Feast of Flames',
#   'Group': 'Book',
#   'SalesRank': 168596,
#   'Copurchased': '1567184960',
#   'Categories': 'religion book base spiritu wicca religion witchcraft subject earth',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0486287785': {'Id': '3',
#   'ASIN': '0486287785',
#   'Title': 'World War II Allied Fighter Planes Trading Cards',
#   'Group': 'Book',
#   'SalesRank': 1270652,
#   'Copurchased': '',
#   'Categories': 'garden home craft book subject hobbi gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0842328327': {'Id': '4',
#   'ASIN': '0842328327',
#   'Title': 'Life Application Bible Commentary: 1 and 2 Timothy and Titus',
#   'Group': 'Book',
#   'SalesRank': 631289,
#   'Copurchased': '0842328572',
#   'Categories': 'refer studi sacr spiritu applic live christian book new commentari bibl discipleship text translat religion guid life bibl testament subject histori gener christian',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1577943082': {'Id': '5',
#   'ASIN': '1577943082',
#   'Title': 'Prayers That Avail Much for Business: Executive',
#   'Group': 'Book',
#   'SalesRank': 455160,
#   'Copurchased': '',
#   'Categories': 'busi christian religion prayerbook book spiritu subject devot live worship christian',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0486220125': {'Id': '6',
#   'ASIN': '0486220125',
#   'Title': 'How the Other Half Lives: Studies Among the Tenements of New York',
#   'Group': 'Book',
#   'SalesRank': 188784,
#   'Copurchased': '0486401960',
#   'Categories': 'scienc essay categori photo art photographi unit urban sociolog america jewish book nonfict camera state social subject histori gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0231118597': {'Id': '8',
#   'ASIN': '0231118597',
#   'Title': 'Losing Matt Shepard',
#   'Group': 'Book',
#   'SalesRank': 277409,
#   'Copurchased': '080148605X',
#   'Categories': 'nonfict polit criminolog book gay crimin crime lesbian subject gener u',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1859677800': {'Id': '9',
#   'ASIN': '1859677800',
#   'Title': 'Making Bread: The Taste of Traditional Home-Baking',
#   'Group': 'Book',
#   'SalesRank': 949166,
#   'Copurchased': '',
#   'Categories': 'book food cook bake subject bread wine',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0375709363': {'Id': '10',
#   'ASIN': '0375709363',
#   'Title': 'The Edward Said Reader',
#   'Group': 'Book',
#   'SalesRank': 220379,
#   'Copurchased': '0679730672',
#   'Categories': 'critic nonfict fiction scienc polit cultur book literatur theori social subject anthropolog histori gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0871318237': {'Id': '11',
#   'ASIN': '0871318237',
#   'Title': 'Resetting the Clock : Five Anti-Aging Hormones That Improve and Extend Life',
#   'Group': 'Book',
#   'SalesRank': 412962,
#   'Copurchased': '0553577514 0962741817',
#   'Categories': 'holist medicin altern specialti book bodi health technic medic store unknown jp mind profession subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1590770218': {'Id': '12',
#   'ASIN': '1590770218',
#   'Title': 'Fantastic Food with Splenda : 160 Great Recipes for Meals Low in Sugar, Carbohydrates, Fat, and Calories',
#   'Group': 'Book',
#   'SalesRank': 24741,
#   'Copurchased': '',
#   'Categories': 'free diabet fat cook diet low carbohydr ingredi carb herb book diet special loss mind weight health food condiment bodi condit sugar subject nutrit wine gener spice',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0313230269': {'Id': '13',
#   'ASIN': '0313230269',
#   'Title': 'Clockwork Worlds : Mechanized Environments in SF (Contributions to the Study of Science Fiction and Fantasy)',
#   'Group': 'Book',
#   'SalesRank': 2895088,
#   'Copurchased': '',
#   'Categories': 'critic fiction book literatur theori fantasi subject histori gener scienc',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1559362022': {'Id': '15',
#   'ASIN': '1559362022',
#   'Title': 'Wake Up and Smell the Coffee',
#   'Group': 'Book',
#   'SalesRank': 518927,
#   'Copurchased': '1559360968 1559361247',
#   'Categories': 'author photographi unit fiction z eric book theater literatur drama bogosian state b subject gener perform art',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0195110382': {'Id': '16',
#   'ASIN': '0195110382',
#   'Title': 'War at Sea: A Naval History of World War II',
#   'Group': 'Book',
#   'SalesRank': 631564,
#   'Copurchased': '1585741485 0140246967',
#   'Categories': 'war book world militari ii subject naval gener histori',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0849311012': {'Id': '17',
#   'ASIN': '0849311012',
#   'Title': 'Telecommunications Cost Management',
#   'Group': 'Book',
#   'SalesRank': 570183,
#   'Copurchased': '1578200326',
#   'Categories': 'telecommun amazon com internet econom manag store busi hardwar comput offic design manufactur industri home book engin microprocessor leadership system invest subject oper system gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '078510870X': {'Id': '19',
#   'ASIN': '078510870X',
#   'Title': 'Ultimate Marvel Team-Up',
#   'Group': 'Book',
#   'SalesRank': 612475,
#   'Copurchased': '',
#   'Categories': 'novel graphic fiction mysteri book horror literatur fantasi marvel teen superhero scienc subject comic publish children',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '3895780812': {'Id': '20',
#   'ASIN': '3895780812',
#   'Title': 'Computed Tomography : Fundamentals, System Technology, Image Quality, Applications',
#   'Group': 'Book',
#   'SalesRank': 179448,
#   'Copurchased': '0071343547 0819444251',
#   'Categories': 'medicin comput book radiolog internet technic medic intern profession subject gener specialti',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0393049388': {'Id': '23',
#   'ASIN': '0393049388',
#   'Title': 'Strange Fire: A Novel',
#   'Group': 'Book',
#   'SalesRank': 1277867,
#   'Copurchased': '',
#   'Categories': 'contemporari thriller fiction book literatur subject gener mysteri',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0553525476': {'Id': '24',
#   'ASIN': '0553525476',
#   'Title': 'The Casebook of Sherlock Holmes, Volume 2 (Casebook of Sherlock Holmes)',
#   'Group': 'Book',
#   'SalesRank': 1545277,
#   'Copurchased': '',
#   'Categories': 'conan z detect mysteri sir british broadcast holm thriller book sherlock format show tape author entertain doyl arthur subject radio gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0939165252': {'Id': '25',
#   'ASIN': '0939165252',
#   'Title': 'Jailed for Freedom: American Women Win the Vote',
#   'Group': 'Book',
#   'SalesRank': 326756,
#   'Copurchased': '',
#   'Categories': 'nonfict studi book elect govern subject histori women',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1590930509': {'Id': '26',
#   'ASIN': '1590930509',
#   'Title': 'Chicken Little',
#   'Group': 'Book',
#   'SalesRank': 242571,
#   'Copurchased': '0899193498',
#   'Categories': 'pictur tale folk book literatur fairi stori subject age myth gener children',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0231096704': {'Id': '27',
#   'ASIN': '0231096704',
#   'Title': 'The Columbia Anthology of Gay Literature',
#   'Group': 'Book',
#   'SalesRank': 1119683,
#   'Copurchased': '',
#   'Categories': 'group nonfict fiction scienc classic studi book gay literatur special social lesbian subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1893732290': {'Id': '28',
#   'ASIN': '1893732290',
#   'Title': "God Knows Marriage Isn't Always Easy: 12 Ways to Add Zest (God Knows)",
#   'Group': 'Book',
#   'SalesRank': 745886,
#   'Copurchased': '',
#   'Categories': 'christian marriag faith religion relationship book spiritu subject live christian',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0781718791': {'Id': '29',
#   'ASIN': '0781718791',
#   'Title': 'Advanced Pediatric Clinical Assessment: Skills and Procedures',
#   'Group': 'Book',
#   'SalesRank': 677416,
#   'Copurchased': '',
#   'Categories': 'assess medicin diagnosi book pediatr neonat technic medic profession subject gener nurs pediatr specialti',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0471150274': {'Id': '30',
#   'ASIN': '0471150274',
#   'Title': 'Solving Statics Problems with MathCAD',
#   'Group': 'Book',
#   'SalesRank': 227883,
#   'Copurchased': '1852331666',
#   'Categories': 'mechan mechan specialti engin book advanc civil aerospac store unknown jp subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0895872218': {'Id': '31',
#   'ASIN': '0895872218',
#   'Title': 'Backroad Buffets & Country Cafes: A Southern Guide to Meat-And-Threes & Down-Home Dining',
#   'Group': 'Book',
#   'SalesRank': 507787,
#   'Copurchased': '1892514656',
#   'Categories': 'amazon dine profess com industri categori cook store gener busi unit lodg travel intern offic tourism home book hospit food region state invest subject south wine region u',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0761116982': {'Id': '32',
#   'ASIN': '0761116982',
#   'Title': 'Staff Meals from Chanterelle',
#   'Group': 'Book',
#   'SalesRank': 150657,
#   'Copurchased': '',
#   'Categories': 'gastronomi book food middl wine region cook intern subject histori profession atlant gener u',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0439240751': {'Id': '33',
#   'ASIN': '0439240751',
#   'Title': 'Double Jeopardy (T*Witches, 6)',
#   'Group': 'Book',
#   'SalesRank': 97166,
#   'Copurchased': '0439240727 0439240700',
#   'Categories': 'seri witch store subject mysteri scienc children fiction horror twin jp magic book literatur fantasi teen issu specialti unknown adventur',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0618111212': {'Id': '35',
#   'ASIN': '0618111212',
#   'Title': 'Burnt Toast on Davenport Street',
#   'Group': 'Book',
#   'SalesRank': 317983,
#   'Copurchased': '',
#   'Categories': 'pictur humor fiction anim book literatur horror fantasi dog children subject age gener mysteri scienc magic',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1898630038': {'Id': '36',
#   'ASIN': '1898630038',
#   'Title': 'Uists & Barra (Pevensey Island guides)',
#   'Group': 'Book',
#   'SalesRank': 1406353,
#   'Copurchased': '',
#   'Categories': 'europ amazon com book scotland travel store categori subject great gener britain',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0787950599': {'Id': '38',
#   'ASIN': '0787950599',
#   'Title': 'Resolving Conflicts At Work : A Complete Guide for Everyone on the Job',
#   'Group': 'Book',
#   'SalesRank': 644042,
#   'Copurchased': '014028852X',
#   'Categories': 'human amazon profess com industri internet manag store counsel busi personnel comput resourc occup success offic home comput digit book primer mind health organiz manag cultur guid life bodi comput psycholog invest secret subject biographi gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0312199406': {'Id': '39',
#   'ASIN': '0312199406',
#   'Title': 'Night of Many Dreams : A Novel',
#   'Group': 'Book',
#   'SalesRank': 57186,
#   'Copurchased': '0312267568',
#   'Categories': 'contemporari fiction book club specialti book literatur store subject popular gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1573221740': {'Id': '40',
#   'ASIN': '1573221740',
#   'Title': 'Renovations: A Father and Son Rebuild a House and Rediscover Each Other',
#   'Group': 'Book',
#   'SalesRank': 678019,
#   'Copurchased': '',
#   'Categories': 'garden home famili child famili relationship book parent memoir remodel adult renov parent subject biographi design gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0130132543': {'Id': '41',
#   'ASIN': '0130132543',
#   'Title': 'Workbook: The Long-Term Care Nursing Assistant',
#   'Group': 'Book',
#   'SalesRank': 2014896,
#   'Copurchased': '',
#   'Categories': 'medicin care book physician refer hospic technic medic profession subject patient nurs',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0486268780': {'Id': '43',
#   'ASIN': '0486268780',
#   'Title': 'Selected Poems (Dover Thrift Editions)',
#   'Group': 'Book',
#   'SalesRank': 260300,
#   'Copurchased': '0486275507 0486401588 0486272737 0486285537',
#   'Categories': 'author unit fiction z classic whitman book singl world literatur state w th centuri walt poetri gener subject',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1861007418': {'Id': '45',
#   'ASIN': '1861007418',
#   'Title': 'Beginning ASP.NET Databases using C#',
#   'Group': 'Book',
#   'SalesRank': 48408,
#   'Copurchased': '1861006098',
#   'Categories': 'eschatolog databas tool internet program web comput spiritu server page c book languag activ religion theolog subject gener christian',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0826449379': {'Id': '46',
#   'ASIN': '0826449379',
#   'Title': "Alternative Worlds in Fantasy Fiction (Contemporary Classics of Children's Literature)",
#   'Group': 'Book',
#   'SalesRank': 1115213,
#   'Copurchased': '0380651939',
#   'Categories': 'critic famili fiction classic guid book parent literatur theori read fantasi teen subject histori gener scienc',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0590568833': {'Id': '47',
#   'ASIN': '0590568833',
#   'Title': 'How to Kill a Monster (Goosebumps)',
#   'Group': 'Book',
#   'SalesRank': 654748,
#   'Copurchased': '',
#   'Categories': 'z obsess monster mysteri scienc children fiction illustr horror r age book literatur fantasi author stine spine chill subject l gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0439420717': {'Id': '48',
#   'ASIN': '0439420717',
#   'Title': 'Scooby-doo Mysteries #24 (Scooby-Doo Mysteries)',
#   'Group': 'Book',
#   'SalesRank': 529184,
#   'Copurchased': '0439284899',
#   'Categories': 'seri doo z detect j mysteri scienc espionag children fiction jame horror mysteri detect book literatur fantasi scoobi author humor cultur spine chill subject popular del',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0687054532': {'Id': '51',
#   'ASIN': '0687054532',
#   'Title': 'Out on the Edge: A Wake-Up Call for Church Leaders on the Edge of the Media Reformation',
#   'Group': 'Book',
#   'SalesRank': 505266,
#   'Copurchased': '',
#   'Categories': 'christian religion pentecost book clergi ministri spiritu church histori subject gener protestant',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0875420532': {'Id': '52',
#   'ASIN': '0875420532',
#   'Title': "Secrets of Gypsy Love Magick (Llewellyn's New Age Series)",
#   'Group': 'Book',
#   'SalesRank': 409481,
#   'Copurchased': '',
#   'Categories': 'occult folklor scienc romanc love spiritu sociolog magic relationship book occult mind health nonfict religion bodi mytholog social subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0944708498': {'Id': '53',
#   'ASIN': '0944708498',
#   'Title': 'Baby Boomer Retirement: 65 Simple Ways to Protect Your Future',
#   'Group': 'Book',
#   'SalesRank': 566643,
#   'Copurchased': '',
#   'Categories': 'amazon financ com store busi famili age plan parent offic home book parent financi person retir invest subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0613100093': {'Id': '54',
#   'ASIN': '0613100093',
#   'Title': 'Betsy & Tacy Go over the Big Hill (Betsy and Tacy Books)',
#   'Group': 'Book',
#   'SalesRank': 629348,
#   'Copurchased': '0064401111',
#   'Categories': 'seri taci peopl fiction classic friendship situat book literatur place action social subject age gener betsi adventur children',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0486275035': {'Id': '55',
#   'ASIN': '0486275035',
#   'Title': 'Goldilocks and the Three Bears : Full-Color Picture Book (Dover Little Activity Books)',
#   'Group': 'Book',
#   'SalesRank': 1269904,
#   'Copurchased': '',
#   'Categories': 'humor book literatur subject age gener children',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1550416243': {'Id': '56',
#   'ASIN': '1550416243',
#   'Title': 'Three Bricks Shy of a Load: A Collection of True Stories About Ordinary People Doing Really Dumb Stuff!',
#   'Group': 'Book',
#   'SalesRank': 2167012,
#   'Copurchased': '',
#   'Categories': 'humor entertain book essay subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0398068917': {'Id': '57',
#   'ASIN': '0398068917',
#   'Title': 'Investigating Computer Crime: A Primer for Security Managers',
#   'Group': 'Book',
#   'SalesRank': 1501773,
#   'Copurchased': '',
#   'Categories': 'busi home amazon comput cultur comput digit book com hacker internet manag store project offic subject gener secur',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '087842461X': {'Id': '58',
#   'ASIN': '087842461X',
#   'Title': 'Raptors of the Rockies: Biology of the Birds of Prey and Species Accounts of the Raptors of the Rockies',
#   'Group': 'Book',
#   'SalesRank': 1091842,
#   'Copurchased': '',
#   'Categories': 'bird refer store subject rocki unit jp field mountain book natur guid specialti birdwatch region state unknown gener outdoor',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0393971694': {'Id': '60',
#   'ASIN': '0393971694',
#   'Title': 'Renaissance Music: Music in Western Europe, 1400-1600 (Norton Introduction to Music History)',
#   'Group': 'Book',
#   'SalesRank': 373682,
#   'Copurchased': '039395272X',
#   'Categories': 'critic entertain specialti book textbook appreci new art use human store music subject histori gener europ',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1550373080': {'Id': '61',
#   'ASIN': '1550373080',
#   'Title': 'Hermanos (Hablemos)',
#   'Group': 'Book',
#   'SalesRank': 890775,
#   'Copurchased': '',
#   'Categories': 'famili español año children juvenil bebe multilingu sibl book infantil spanish format place en peopl nonfict life libro subject',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0026879077': {'Id': '62',
#   'ASIN': '0026879077',
#   'Title': 'Scoring High on the Stanford Achievement Test',
#   'Group': 'Book',
#   'SalesRank': 1157369,
#   'Copurchased': '0026879018 1930288034',
#   'Categories': 'nonfict book school refer educ subject children',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0966723821': {'Id': '63',
#   'ASIN': '0966723821',
#   'Title': 'Historia De Cancer De Una Dietista : Informacion & Inspiracion para la Recuperacion & Curacion Sobreviviente de tres canceres',
#   'Group': 'Book',
#   'SalesRank': 613909,
#   'Copurchased': '',
#   'Categories': 'academ medic español disord cancer diseas oncolog topic book diet loss special format intern mind weight health biografía en medicin altern profession memoria memoir bodi condit libro subject biographi nutrit gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0689846088': {'Id': '64',
#   'ASIN': '0689846088',
#   'Title': 'A Charlie Brown Christmas',
#   'Group': 'Book',
#   'SalesRank': 423424,
#   'Copurchased': '',
#   'Categories': 'pictur peopl fiction book place holiday subject age festiv christma gener children',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0273651870': {'Id': '65',
#   'ASIN': '0273651870',
#   'Title': 'Economics for Business',
#   'Group': 'Book',
#   'SalesRank': 963890,
#   'Copurchased': '0131000691 053438367X',
#   'Categories': 'busi home amazon com book invest store subject offic gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0393037622': {'Id': '66',
#   'ASIN': '0393037622',
#   'Title': 'Blood and Guts: A Short History of Medicine',
#   'Group': 'Book',
#   'SalesRank': 408761,
#   'Copurchased': '',
#   'Categories': 'topic medicin mathemat book special subject histori gener scienc',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1571515429': {'Id': '67',
#   'ASIN': '1571515429',
#   'Title': 'Picture Me With My Friend Jesus: Girl Version (Picture Me)',
#   'Group': 'Book',
#   'SalesRank': 784192,
#   'Copurchased': '',
#   'Categories': 'jesu christian fiction book biographi religion subject age christian children',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0810114275': {'Id': '68',
#   'ASIN': '0810114275',
#   'Title': 'Experiencing and the Creation of Meaning: A Philosophical and Psychological Approach to the Subjective (Studies in Phenomenology and Existential Philosophy)',
#   'Group': 'Book',
#   'SalesRank': 421103,
#   'Copurchased': '',
#   'Categories': 'modern nonfict book philosophi epistemolog movement phenomenolog subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0415925398': {'Id': '69',
#   'ASIN': '0415925398',
#   'Title': 'Negotiated Empires: Centers and Peripheries in the New World, 1500-1820',
#   'Group': 'Book',
#   'SalesRank': 454490,
#   'Copurchased': '',
#   'Categories': 'histor america book subject historiographi histori studi gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0415223954': {'Id': '70',
#   'ASIN': '0415223954',
#   'Title': 'Geographies of Young People: The Morally Contested Spaces of Identity (Critical Geographies)',
#   'Group': 'Book',
#   'SalesRank': 973410,
#   'Copurchased': '',
#   'Categories': 'human nonfict studi scienc geographi book social subject gener sociolog children',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '157281196X': {'Id': '72',
#   'ASIN': '157281196X',
#   'Title': 'Power of Flowers: An Archetypal Journey Through Nature',
#   'Group': 'Book',
#   'SalesRank': 348412,
#   'Copurchased': '1572812575 1879181894',
#   'Categories': 'divin entertain religion book card spiritu new game tarot subject age gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0375803394': {'Id': '73',
#   'ASIN': '0375803394',
#   'Title': 'The Perfect Plan (7th Heaven)',
#   'Group': 'Book',
#   'SalesRank': 561551,
#   'Copurchased': '',
#   'Categories': 'seri peopl popular famili cultur life book literatur place religion seventh subject age heaven gener christian children',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0113300174': {'Id': '74',
#   'ASIN': '0113300174',
#   'Title': 'Service Delivery (It Infrastructure Library Series)',
#   'Group': 'Book',
#   'SalesRank': 27507,
#   'Copurchased': '',
#   'Categories': 'busi home amazon profil book com refer invest compani manag store leadership biographi offic subject gener scienc primer',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0786863919': {'Id': '75',
#   'ASIN': '0786863919',
#   'Title': 'Disney A to Z : The Updated Official Encyclopedia (Disney a to Z)',
#   'Group': 'Book',
#   'SalesRank': 161879,
#   'Copurchased': '',
#   'Categories': 'garden home entertain cultur book pop americana refer art collect televis movi subject antiqu encyclopedia',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1581150040': {'Id': '76',
#   'ASIN': '1581150040',
#   'Title': "The Writer's Legal Guide (2nd ed)",
#   'Group': 'Book',
#   'SalesRank': 1151885,
#   'Copurchased': '',
#   'Categories': 'write intellectu patent guid practic book law authorship copyright refer publish technic properti subject trademark profession practic gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0312982178': {'Id': '77',
#   'ASIN': '0312982178',
#   'Title': 'Water Touching Stone',
#   'Group': 'Book',
#   'SalesRank': 27012,
#   'Copurchased': '',
#   'Categories': 'thriller book subject gener mysteri',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0874850037': {'Id': '78',
#   'ASIN': '0874850037',
#   'Title': 'The Ebony Cookbook: A Date With a Dish',
#   'Group': 'Book',
#   'SalesRank': 140480,
#   'Copurchased': '',
#   'Categories': 'book food region cook intern subject american wine african u gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0811726371': {'Id': '79',
#   'ASIN': '0811726371',
#   'Title': "Today's Military Wife: Meeting the Challenges of Service Life (Today's Military Wife)",
#   'Group': 'Book',
#   'SalesRank': 7437,
#   'Copurchased': '',
#   'Categories': 'nonfict studi book refer subject gener women',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1884997015': {'Id': '80',
#   'ASIN': '1884997015',
#   'Title': 'In Quest of God: The Saga of an Extraordinary Pilgrimage',
#   'Group': 'Book',
#   'SalesRank': 533031,
#   'Copurchased': '1573227153',
#   'Categories': 'author z religion book e spiritu memoir religion easwaran subject biographi eknath eastern gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0140430407': {'Id': '82',
#   'ASIN': '0140430407',
#   'Title': 'Puddnhead Wilson : And, Those Extraordinary Twins (The Penguin English Library)',
#   'Group': 'Book',
#   'SalesRank': 60668,
#   'Copurchased': '0140186867',
#   'Categories': 'author unit fiction classic z book world literatur mark state subject th centuri twain gener paperback',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '059516630X': {'Id': '83',
#   'ASIN': '059516630X',
#   'Title': 'A Candle for Bobby',
#   'Group': 'Book',
#   'SalesRank': 3272795,
#   'Copurchased': '',
#   'Categories': 'contemporari fiction book literatur subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0912500476': {'Id': '85',
#   'ASIN': '0912500476',
#   'Title': 'Amamantar Sencillo y Puro',
#   'Group': 'Book',
#   'SalesRank': 1246085,
#   'Copurchased': '',
#   'Categories': 'babi famili video specialti book parent parent toddler categori feed subject store music breastfeed',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0807205249': {'Id': '86',
#   'ASIN': '0807205249',
#   'Title': 'Junie B. Jones Collection: Books 9-12',
#   'Group': 'Book',
#   'SalesRank': 1525696,
#   'Copurchased': '',
#   'Categories': 'fiction book literatur format children gener tape',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0415157528': {'Id': '87',
#   'ASIN': '0415157528',
#   'Title': 'Colloquial Polish: The Complete Course for Beginners (Colloquial Series (Book Only))',
#   'Group': 'Book',
#   'SalesRank': 393166,
#   'Copurchased': '0415224373',
#   'Categories': 'dictionari book languag polish thesaurus refer foreign subject languag gener instruct english',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '039802278X': {'Id': '88',
#   'ASIN': '039802278X',
#   'Title': 'Normal and Abnormal Development: The Influence of Primitive Reflexes on Motor Development',
#   'Group': 'Book',
#   'SalesRank': 353149,
#   'Copurchased': '',
#   'Categories': '',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0671727737': {'Id': '90',
#   'ASIN': '0671727737',
#   'Title': 'The Eagle Has Landed',
#   'Group': 'Book',
#   'SalesRank': 841921,
#   'Copurchased': '0671746693 0425138232',
#   'Categories': 'thriller tale book intrigu stori subject spi mysteri',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1566913810': {'Id': '91',
#   'ASIN': '1566913810',
#   'Title': 'Foghorn Outdoors: New England Hiking 3 Ed: The Complete Guide to More than 380 Hikes',
#   'Group': 'Book',
#   'SalesRank': 333198,
#   'Copurchased': '0881504548',
#   'Categories': 'amazon unit england com book new state travel store categori subject northeast region',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '037575380X': {'Id': '92',
#   'ASIN': '037575380X',
#   'Title': 'Black No More : A Novel (Modern Library (Paperback))',
#   'Group': 'Book',
#   'SalesRank': 251469,
#   'Copurchased': '0807009199',
#   'Categories': 'contemporari unit fiction classic book world literatur short state stori subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0965740056': {'Id': '93',
#   'ASIN': '0965740056',
#   'Title': 'BizPricer¿ Business Valuation Manual w/Software',
#   'Group': 'Book',
#   'SalesRank': 1485593,
#   'Copurchased': '',
#   'Categories': 'busi home amazon financ com book entrepreneurship corpor invest store subject offic gener small',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '039572774X': {'Id': '94',
#   'ASIN': '039572774X',
#   'Title': 'The American Heritage Dictionary of Idioms',
#   'Group': 'Book',
#   'SalesRank': 166549,
#   'Copurchased': '0590381571',
#   'Categories': 'dictionari book slang thesaurus refer subject idiom gener english',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0887402631': {'Id': '95',
#   'ASIN': '0887402631',
#   'Title': 'The Heavy Flak Guns, 1933-1945: 88Mm, 105Mm, 128Mm, 150Mm, and Ballistic Directional Equipment',
#   'Group': 'Book',
#   'SalesRank': 1369585,
#   'Copurchased': '',
#   'Categories': 'technolog book subject histori scienc',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0310485002': {'Id': '96',
#   'ASIN': '0310485002',
#   'Title': 'Becoming a Contagious Christian',
#   'Group': 'Book',
#   'SalesRank': 215846,
#   'Copurchased': '1576832201',
#   'Categories': 'inspir christian christian religion book spiritu discipleship subject live gener protestant',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '042515517X': {'Id': '97',
#   'ASIN': '042515517X',
#   'Title': 'Year of the Tiger',
#   'Group': 'Book',
#   'SalesRank': 509767,
#   'Copurchased': '0425176312 0671725319',
#   'Categories': 'contemporari thriller tale fiction book literatur intrigu stori subject gener spi mysteri',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0071402306': {'Id': '99',
#   'ASIN': '0071402306',
#   'Title': "An Employee's Guide to Stock Options",
#   'Group': 'Book',
#   'SalesRank': 228734,
#   'Copurchased': '',
#   'Categories': 'busi account home person financ amazon com book option invest technic store subject offic profession gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0787958743': {'Id': '100',
#   'ASIN': '0787958743',
#   'Title': 'Guide to Effective Staff Development in Health Care Organizations : A Systems Approach to Successful Training (J-B AHA Press)',
#   'Group': 'Book',
#   'SalesRank': 783690,
#   'Copurchased': '',
#   'Categories': 'polici medicin book econom administr technic medic profession subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0743509315': {'Id': '101',
#   'ASIN': '0743509315',
#   'Title': 'Separation Of Power',
#   'Group': 'Book',
#   'SalesRank': 612868,
#   'Copurchased': '0671023209',
#   'Categories': 'thriller tale fiction mysteri book literatur genr intrigu format stori polit subject spi suspens gener cd',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1858685486': {'Id': '102',
#   'ASIN': '1858685486',
#   'Title': 'Mensa Visual Brainteasers',
#   'Group': 'Book',
#   'SalesRank': 576507,
#   'Copurchased': '0201135493',
#   'Categories': 'puzzl entertain logic teaser book game brain subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0151803870': {'Id': '103',
#   'ASIN': '0151803870',
#   'Title': 'Selected Essays',
#   'Group': 'Book',
#   'SalesRank': 324548,
#   'Copurchased': '015121185X 0811201511',
#   'Categories': 'author fiction z religion classic eliot book literatur spiritu essay subject e gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0820451576': {'Id': '104',
#   'ASIN': '0820451576',
#   'Title': 'Owning Culture: Authorship, Ownership, and Intellectual Property Law (Popular Culture and Everyday Life, Vol. 1)',
#   'Group': 'Book',
#   'SalesRank': 592661,
#   'Copurchased': '1573928895',
#   'Categories': 'busi intellectu book law technic properti subject profession gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1555919332': {'Id': '105',
#   'ASIN': '1555919332',
#   'Title': 'Learning in Overdrive: Designing Curriculum, Instruction, and Assessment from Standards : A Manual for Teachers',
#   'Group': 'Book',
#   'SalesRank': 114176,
#   'Copurchased': '',
#   'Categories': 'assess nonfict financ lesson book pedagogi plan theori educ technic standard subject profession gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0821825917': {'Id': '106',
#   'ASIN': '0821825917',
#   'Title': 'Filtrations on the Homology of Algebraic Varieties (Memoirs of the American Mathematical Society, 529)',
#   'Group': 'Book',
#   'SalesRank': 1646865,
#   'Copurchased': '',
#   'Categories': 'mathemat book subject gener scienc',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '038548125X': {'Id': '107',
#   'ASIN': '038548125X',
#   'Title': 'Mothers and Daughters',
#   'Group': 'Book',
#   'SalesRank': 432141,
#   'Copurchased': '',
#   'Categories': 'scienc famili essay categori photo art famili photographi motherhood sociolog marriag relationship book parent nonfict camera social subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0838531377': {'Id': '108',
#   'ASIN': '0838531377',
#   'Title': 'General Ophthalmology',
#   'Group': 'Book',
#   'SalesRank': 635566,
#   'Copurchased': '0891283463',
#   'Categories': 'otolaryngolog medicin book technic medic profession subject ophthalmolog surgeri specialti',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0471346608': {'Id': '109',
#   'ASIN': '0471346608',
#   'Title': 'Baby Basics : A Guide for New Parents',
#   'Group': 'Book',
#   'SalesRank': 502928,
#   'Copurchased': '0764565168',
#   'Categories': 'store famili video parent toddler childbirth music babi book parent mind health women develop person pregnanc infant specialti bodi subject infant gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0684868008': {'Id': '110',
#   'ASIN': '0684868008',
#   'Title': 'Casanova in Bohemia : A Novel',
#   'Group': 'Book',
#   'SalesRank': 92775,
#   'Copurchased': '',
#   'Categories': 'histor z classic music wolfgang fiction genr music book literatur genr amadeu compos peopl entertain mozart memoir subject biographi',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0736805656': {'Id': '111',
#   'ASIN': '0736805656',
#   'Title': 'The Maine Coon Cat (Learning About Cats)',
#   'Group': 'Book',
#   'SalesRank': 1612259,
#   'Copurchased': '',
#   'Categories': 'nonfict anim pet book subject cat children',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1572315938': {'Id': '112',
#   'ASIN': '1572315938',
#   'Title': 'Official Microsoft Image Composer Book',
#   'Group': 'Book',
#   'SalesRank': 682312,
#   'Copurchased': '',
#   'Categories': 'web develop illustr comput compos book commerc graphic html site internet imag applic design subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0736625801': {'Id': '113',
#   'ASIN': '0736625801',
#   'Title': 'Jesus: A Life',
#   'Group': 'Book',
#   'SalesRank': 2213377,
#   'Copurchased': '0140144994',
#   'Categories': '',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0809240394': {'Id': '114',
#   'ASIN': '0809240394',
#   'Title': 'Bowl Like a Pro',
#   'Group': 'Book',
#   'SalesRank': 887935,
#   'Copurchased': '',
#   'Categories': 'book bowl subject individu sport gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0533139317': {'Id': '115',
#   'ASIN': '0533139317',
#   'Title': 'Growing Millionaire Kids',
#   'Group': 'Book',
#   'SalesRank': 1217413,
#   'Copurchased': '',
#   'Categories': 'busi home amazon com book invest store subject offic gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0820112518': {'Id': '116',
#   'ASIN': '0820112518',
#   'Title': 'The Life of Benjamin West',
#   'Group': 'Book',
#   'SalesRank': 3312631,
#   'Copurchased': '',
#   'Categories': 'photographi benjamin west v z book memoir artist subject biographi gener art',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0380819546': {'Id': '117',
#   'ASIN': '0380819546',
#   'Title': 'Site Unseen : An Emma Fielding Mystery (Emma Fielding Mysteries)',
#   'Group': 'Book',
#   'SalesRank': 38915,
#   'Copurchased': '',
#   'Categories': 'thriller seri sleuth mysteri book subject gener women',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0590464272': {'Id': '118',
#   'ASIN': '0590464272',
#   'Title': 'The Magic School Bus At The Waterworks : (autobus Magico Viaja Por...) (Magic School Bus)',
#   'Group': 'Book',
#   'SalesRank': 654728,
#   'Copurchased': '',
#   'Categories': 'seri z joanna school ficción español año scienc children juvenil fiction work illustr age magic c bu reader book literatur infantil natur format earli action en author cole pictur bruce libro subject adventur degen',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0849943221': {'Id': '119',
#   'ASIN': '0849943221',
#   'Title': 'Black Friday (Soul Survivor Series, Bk. 4)',
#   'Group': 'Book',
#   'SalesRank': 762209,
#   'Copurchased': '0849942993',
#   'Categories': 'thriller author tale fiction z religion book spiritu intrigu lahay stori tim subject l gener spi mysteri paperback',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0140445684': {'Id': '120',
#   'ASIN': '0140445684',
#   'Title': 'Capital : A Critique of Political Economy (Penguin Classics)',
#   'Group': 'Book',
#   'SalesRank': 17693,
#   'Copurchased': '0879757051 1573921394',
#   'Categories': 'nonfict social polit book philosophi ideolog radic thought subject commun gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0688060676': {'Id': '121',
#   'ASIN': '0688060676',
#   'Title': 'Ten Black Dots',
#   'Group': 'Book',
#   'SalesRank': 144348,
#   'Copurchased': '0440404959 0688147402 0689808925',
#   'Categories': 'z store children basic illustr concept music donald age concept crew babi c babi book author specialti subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '059047913X': {'Id': '123',
#   'ASIN': '059047913X',
#   'Title': 'You Can Name 100 Dinosaurs!',
#   'Group': 'Book',
#   'SalesRank': 651510,
#   'Copurchased': '',
#   'Categories': 'nonfict babi anim book dinosaur subject gener children',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '076453243X': {'Id': '125',
#   'ASIN': '076453243X',
#   'Title': 'Adobe® InDesign¿ Bible',
#   'Group': 'Book',
#   'SalesRank': 405530,
#   'Copurchased': '',
#   'Categories': 'web develop illustr adob comput book graphic internet publish desktop subject design html gener indesign',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0395530377': {'Id': '126',
#   'ASIN': '0395530377',
#   'Title': 'Houghton Mifflin Mathematics: Practice Activity Level 7',
#   'Group': 'Book',
#   'SalesRank': 1804602,
#   'Copurchased': '',
#   'Categories': 'math mathemat work technolog book natur teen subject gener scienc children',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0878301534': {'Id': '127',
#   'ASIN': '0878301534',
#   'Title': 'Ballroom Dancing',
#   'Group': 'Book',
#   'SalesRank': 36535,
#   'Copurchased': '',
#   'Categories': 'perform photographi book art refer danc popular subject gener ballroom',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0312871880': {'Id': '128',
#   'ASIN': '0312871880',
#   'Title': 'Irish Stew!',
#   'Group': 'Book',
#   'SalesRank': 368790,
#   'Copurchased': '0812590236',
#   'Categories': 'thriller author g seri fiction sleuth z andrew book literatur literari subject greeley gener mysteri women',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1579473024': {'Id': '129',
#   'ASIN': '1579473024',
#   'Title': 'Cpt 2003: Current Procedural Terminology (Cpt / Current Procedural Terminology (Standard Edition))',
#   'Group': 'Book',
#   'SalesRank': 256979,
#   'Copurchased': '1570662592',
#   'Categories': 'record polici medicin book practic econom refer administr scienc technic manag medic reimburs profession subject gener histori',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0767905288': {'Id': '130',
#   'ASIN': '0767905288',
#   'Title': "The O'Reilly Factor: The Good, the Bad, and the Completely Ridiculous in American Life",
#   'Group': 'Book',
#   'SalesRank': 29460,
#   'Copurchased': '0767908481 0060514558',
#   'Categories': 'nonfict polit practic book polit parti subject gener u',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '078795893X': {'Id': '131',
#   'ASIN': '078795893X',
#   'Title': 'The 2R Manager: When to Relate, When to Require, and How to Do Both Effectively',
#   'Group': 'Book',
#   'SalesRank': 122152,
#   'Copurchased': '0743212347 0875849369',
#   'Categories': 'busi home amazon com book entrepreneurship career invest manag store leadership offic subject gener small',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0743504097': {'Id': '132',
#   'ASIN': '0743504097',
#   'Title': 'Iyanla Live! : Back to Basics (Iyanla Live!)',
#   'Group': 'Book',
#   'SalesRank': 868001,
#   'Copurchased': '0743507541',
#   'Categories': 'inspir z philosophi v inspir self spiritu transform iyanla book format mind health tape author person motiv vanzant religion bodi psycholog growth subject help gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0877936528': {'Id': '134',
#   'ASIN': '0877936528',
#   'Title': 'Growing Teen Disciples: Strategies for Really Effective Youth Ministry',
#   'Group': 'Book',
#   'SalesRank': 1646474,
#   'Copurchased': '',
#   'Categories': 'youth religion clergi book ministri spiritu subject christian',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0609608363': {'Id': '135',
#   'ASIN': '0609608363',
#   'Title': 'Wondrous Contrivances : Technology at the Threshold',
#   'Group': 'Book',
#   'SalesRank': 408802,
#   'Copurchased': '',
#   'Categories': 'unit mathemat america technolog book state subject histori gener scienc',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0452011604': {'Id': '136',
#   'ASIN': '0452011604',
#   'Title': 'Understanding Islam: An Introduction to the Muslim World, Third Revised and Updated Edition',
#   'Group': 'Book',
#   'SalesRank': 90195,
#   'Copurchased': '081296618X 0140175962',
#   'Categories': 'religion book spiritu islam subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0781433525': {'Id': '137',
#   'ASIN': '0781433525',
#   'Title': 'Apples of Gold: A Six-Week Nurturing Program for Women',
#   'Group': 'Book',
#   'SalesRank': 129355,
#   'Copurchased': '0781438098 1885904177 0891077197',
#   'Categories': 'inspir christian organ religion institut book clergi spiritu issu church live subject gener christian women',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0824518659': {'Id': '139',
#   'ASIN': '0824518659',
#   'Title': 'The Sacred Impulse',
#   'Group': 'Book',
#   'SalesRank': 846457,
#   'Copurchased': '',
#   'Categories': 'inspir environ christian religion book spiritu natur ecolog subject gener outdoor catholic',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0786710772': {'Id': '140',
#   'ASIN': '0786710772',
#   'Title': 'Power & Greed: A Short History of the World',
#   'Group': 'Book',
#   'SalesRank': 788014,
#   'Copurchased': '',
#   'Categories': 'specialti book world store jp unknown histori subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1886110867': {'Id': '141',
#   'ASIN': '1886110867',
#   'Title': 'Coach K: Building the Duke Dynasty : Building the Duke Dynasty',
#   'Group': 'Book',
#   'SalesRank': 401565,
#   'Copurchased': '0446676780',
#   'Categories': 'book univers basketbal subject biographi colleg sport gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0590108859': {'Id': '142',
#   'ASIN': '0590108859',
#   'Title': 'Chemical Chaos (Horrible Science)',
#   'Group': 'Book',
#   'SalesRank': 280529,
#   'Copurchased': '',
#   'Categories': 'work book natur subject age chemistri gener scienc children',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '080784991X': {'Id': '143',
#   'ASIN': '080784991X',
#   'Title': 'Ghosts from the Coast',
#   'Group': 'Book',
#   'SalesRank': 1079230,
#   'Copurchased': '',
#   'Categories': 'occult folklor scienc collect fiction unit horror spiritu mysteri book world literatur supernatur ghost nonfict religion reader state mytholog social subject gener unexplain',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0195044193': {'Id': '144',
#   'ASIN': '0195044193',
#   'Title': 'The Paradox of Change: American Women in the 20th Century',
#   'Group': 'Book',
#   'SalesRank': 596032,
#   'Copurchased': '025206318X',
#   'Categories': 'nonfict unit studi america book state subject th centuri gener histori women',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1581127723': {'Id': '145',
#   'ASIN': '1581127723',
#   'Title': 'The Bases of Chemical Thermodynamics: Volume 1',
#   'Group': 'Book',
#   'SalesRank': 656347,
#   'Copurchased': '',
#   'Categories': 'chemistri thermodynam theoret chemic book engin physic dynam technic subject physic profession scienc',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0806626062': {'Id': '146',
#   'ASIN': '0806626062',
#   'Title': 'More Prime Time Activities With Kids',
#   'Group': 'Book',
#   'SalesRank': 223675,
#   'Copurchased': '',
#   'Categories': 'garden home famili activ famili video craft specialti book parent parent store music subject hobbi gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0743202554': {'Id': '147',
#   'ASIN': '0743202554',
#   'Title': 'The New Jewish Wedding, Revised',
#   'Group': 'Book',
#   'SalesRank': 11398,
#   'Copurchased': '',
#   'Categories': 'ritual garden home judaism religion jewish book life spiritu refer practic subject gener wed',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0812550749': {'Id': '148',
#   'ASIN': '0812550749',
#   'Title': 'Firebird',
#   'Group': 'Book',
#   'SalesRank': 77008,
#   'Copurchased': '067187750X',
#   'Categories': 'author l fiction z book merced fantasi scienc subject lackey gener paperback',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0764118218': {'Id': '150',
#   'ASIN': '0764118218',
#   'Title': 'Vocabulary Builder: French : Mastering the Most Common French Words and Phrases (Vocabulary Builder Series)',
#   'Group': 'Book',
#   'SalesRank': 966856,
#   'Copurchased': '',
#   'Categories': 'vocabulari french dictionari book languag thesaurus refer word foreign instruct subject languag gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0140272100': {'Id': '154',
#   'ASIN': '0140272100',
#   'Title': 'Vanished',
#   'Group': 'Book',
#   'SalesRank': 274214,
#   'Copurchased': '0140244824',
#   'Categories': 'contemporari fiction book literatur subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0939343347': {'Id': '155',
#   'ASIN': '0939343347',
#   'Title': 'Cowboy Mentality & the Big One That Got Away',
#   'Group': 'Book',
#   'SalesRank': 201196,
#   'Copurchased': '0609610902',
#   'Categories': 'author unit fiction book world literatur singl genr state subject th centuri western poetri gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0842374043': {'Id': '157',
#   'ASIN': '0842374043',
#   'Title': 'What about Spiritual Warfare?',
#   'Group': 'Book',
#   'SalesRank': 1058886,
#   'Copurchased': '',
#   'Categories': 'angelolog christian religion theolog book spiritu religi warfar subject gener angel',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0553487388': {'Id': '159',
#   'ASIN': '0553487388',
#   'Title': 'The Icicle Forest (Fairy School)',
#   'Group': 'Book',
#   'SalesRank': 606246,
#   'Copurchased': '0553487094',
#   'Categories': 'mysteri scienc children antholog fiction folk horror age myth magic friendship book literatur fantasi place tale peopl situat fairi social subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0804119368': {'Id': '160',
#   'ASIN': '0804119368',
#   'Title': 'The Twisted Root (William Monk Novels (Paperback))',
#   'Group': 'Book',
#   'SalesRank': 271715,
#   'Copurchased': '0804118558',
#   'Categories': 'thriller author seri z histor book british p detect subject perri ann suspens mysteri paperback gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0890541795': {'Id': '161',
#   'ASIN': '0890541795',
#   'Title': 'Foliage Plant Diseases: Diagnosis & Control',
#   'Group': 'Book',
#   'SalesRank': 1166713,
#   'Copurchased': '',
#   'Categories': 'garden garden home biolog scienc book hous horticultur biolog scienc plant technic subject profession gener entomolog',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0810939770': {'Id': '162',
#   'ASIN': '0810939770',
#   'Title': 'Wildlife the Nature Paintings of Carl Brenders',
#   'Group': 'Book',
#   'SalesRank': 413356,
#   'Copurchased': '0942620437 068482986X 0316082651',
#   'Categories': 'photographi z book art artist subject histori gener art',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0931892813': {'Id': '163',
#   'ASIN': '0931892813',
#   'Title': 'Messages to Our Family',
#   'Group': 'Book',
#   'SalesRank': 304224,
#   'Copurchased': '0931892333',
#   'Categories': 'occult religion book spiritu new spiritu subject age gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0895296586': {'Id': '164',
#   'ASIN': '0895296586',
#   'Title': "What's Really Wrong With You: A Revolutionary Look at How Muscles Affect Your Health",
#   'Group': 'Book',
#   'SalesRank': 224993,
#   'Copurchased': '0892817402',
#   'Categories': 'medicin diseas altern book disord therapi massag bodi rheumatolog mind technic medic intern profession subject health gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0807842109': {'Id': '165',
#   'ASIN': '0807842109',
#   'Title': 'Passage of Darkness: The Ethnobiology of the Haitian Zombie',
#   'Group': 'Book',
#   'SalesRank': 286627,
#   'Copurchased': '0684839296 0767904028 0792264746',
#   'Categories': 'nonfict scienc religion book tribal spiritu ethnic social practic subject gener sociolog',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0226309045': {'Id': '166',
#   'ASIN': '0226309045',
#   'Title': 'In the Arms of Africa: The Life of Colin Turnbull',
#   'Group': 'Book',
#   'SalesRank': 488085,
#   'Copurchased': '',
#   'Categories': 'group scienc academ psychologist lesbian specif adventur gay explor book anthropolog scientist nonfict profession memoir social subject biographi gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0385332998': {'Id': '167',
#   'ASIN': '0385332998',
#   'Title': 'Total Immersion',
#   'Group': 'Book',
#   'SalesRank': 537058,
#   'Copurchased': '1573228311',
# ...
#   'AvgRating': 0.0},
#  '0684867931': {'Id': '1342',
#   'ASIN': '0684867931',
#   'Title': "Is He Gay? : For Every Woman Who's Met the Ideal Man and is Wondering...Why Hasn't he Tried to Kiss Me?",
#   'Group': 'Book',
#   'SalesRank': 249924,
#   'Copurchased': '',
#   'Categories': 'interperson romanc gener love novel graphic humor marriag relationship book relat sex strip mind health entertain bodi comic subject comic',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0393701700': {'Id': '1344',
#   'ASIN': '0393701700',
#   'Title': 'Words Were Originally Magic',
#   'Group': 'Book',
#   'SalesRank': 105971,
#   'Copurchased': '0393700542',
#   'Categories': 'compuls book behavior bodi psycholog psychotherapi mind health ta counsel gener subject nlp mental',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0761993924': {'Id': '1345',
#   'ASIN': '0761993924',
#   'Title': 'Sex Ratio Patterns in the Indian Population : A Fresh Exploration',
#   'Group': 'Book',
#   'SalesRank': 1971824,
#   'Copurchased': '',
#   'Categories': 'nonfict scienc specialti book textbook new demographi use social store subject gender gener sociolog',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0375762698': {'Id': '1346',
#   'ASIN': '0375762698',
#   'Title': 'Cracking the GRE Psychology Test, 6th Edition (Cracking the Gre Psychology)',
#   'Group': 'Book',
#   'SalesRank': 38783,
#   'Copurchased': '',
#   'Categories': 'central prep guid gre book test bodi psycholog educ refer mind health subject counsel profession graduat train gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0918477638': {'Id': '1347',
#   'ASIN': '0918477638',
#   'Title': 'Serenity of Heart: Bearing the Troubles of This Life',
#   'Group': 'Book',
#   'SalesRank': 1334103,
#   'Copurchased': '',
#   'Categories': 'inspir christian religion book spiritu subject live gener christian catholic',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0762708085': {'Id': '1348',
#   'ASIN': '0762708085',
#   'Title': 'Fun with the Family in Michigan: Hundreds of Ideas for Day Trips with the Kids',
#   'Group': 'Book',
#   'SalesRank': 692681,
#   'Copurchased': '',
#   'Categories': 'amazon unit famili region specialti book com state travel store categori subject gener michigan midwest',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0786868821': {'Id': '1349',
#   'ASIN': '0786868821',
#   'Title': 'Cad: Confessions of a Toxic Bachelor',
#   'Group': 'Book',
#   'SalesRank': 247366,
#   'Copurchased': '0306812274',
#   'Categories': 'group graphic novel entertain humor academ profession book specif journalist memoir comic subject biographi strip gener comic women',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0826314384': {'Id': '1351',
#   'ASIN': '0826314384',
#   'Title': 'Tierra Amarilla: Stories of New Mexico : Cuentos De Nuevo Mexico (Paso Por Aqui)',
#   'Group': 'Book',
#   'SalesRank': 920020,
#   'Copurchased': '',
#   'Categories': 'thriller unit fiction book british literatur world spanish short state stori subject gener mysteri',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0811201511': {'Id': '1352',
#   'ASIN': '0811201511',
#   'Title': 'ABC of Reading',
#   'Group': 'Book',
#   'SalesRank': 202498,
#   'Copurchased': '',
#   'Categories': 'author unit fiction z poetri book world literatur singl p state ezra pound th centuri subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0893343218': {'Id': '1353',
#   'ASIN': '0893343218',
#   'Title': 'Teachers Guide to Community Organization: Strategies for Parent, Teacher and Community Groups to Improve the Schools',
#   'Group': 'Book',
#   'SalesRank': 1898676,
#   'Copurchased': '',
#   'Categories': 'polici group russia nonfict specif book pedagogi memoir educ subject biographi histori gener women',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '030680736X': {'Id': '1354',
#   'ASIN': '030680736X',
#   'Title': 'Dr. Seuss & Mr. Geisel: A Biography',
#   'Group': 'Book',
#   'SalesRank': 97073,
#   'Copurchased': '0876146272',
#   'Categories': 'author charact famili dr book guid seuss book parent literatur biographi art memoir subject popular gener children',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0674008340': {'Id': '1355',
#   'ASIN': '0674008340',
#   'Title': 'Black Rice: The African Origins of Rice Cultivation in the Americas',
#   'Group': 'Book',
#   'SalesRank': 282005,
#   'Copurchased': '',
#   'Categories': 'group nonfict studi scienc book special social subject american african sociolog gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0742512967': {'Id': '1356',
#   'ASIN': '0742512967',
#   'Title': "American Heat: Ethical Problems With the United States' Response to Global Warming (Studies in Social, Political, and Legal Philosophy)",
#   'Group': 'Book',
#   'SalesRank': 846687,
#   'Copurchased': '089608650X',
#   'Categories': 'modern polici environ nonfict polit book philosophi public natur govern u subject conserv gener outdoor',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1558746609': {'Id': '1357',
#   'ASIN': '1558746609',
#   'Title': "Chicken Soup for the Golfer's Soul: Stories of Insight, Inspiration and Laughter on the Links (Chicken Soup Series)",
#   'Group': 'Book',
#   'SalesRank': 476325,
#   'Copurchased': '1558744606',
#   'Categories': 'inspir jack z golf canfield cd inspir self spiritu sport c book format mind health author religion bodi subject spiritu help gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0553214985': {'Id': '1358',
#   'ASIN': '0553214985',
#   'Title': 'A Country Doctor (Bantam Classic)',
#   'Group': 'Book',
#   'SalesRank': 437457,
#   'Copurchased': '',
#   'Categories': 'fiction classic book literatur subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '4333014786': {'Id': '1360',
#   'ASIN': '4333014786',
#   'Title': 'Zen Seeds: Reflections of a Female Priest',
#   'Group': 'Book',
#   'SalesRank': 512876,
#   'Copurchased': '',
#   'Categories': 'nonfict religion book philosophi spiritu buddhism subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0399146261': {'Id': '1361',
#   'ASIN': '0399146261',
#   'Title': 'Three Complete Novels: Cold Fire, Hideaway, Key to Midnight',
#   'Group': 'Book',
#   'SalesRank': 157418,
#   'Copurchased': '0970998716',
#   'Categories': 'author k dean unit z book horror state subject koontz gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0306809389': {'Id': '1365',
#   'ASIN': '0306809389',
#   'Title': 'The Duel for France, 1944: The Men and Battles That Changed the Fate of Europe',
#   'Group': 'Book',
#   'SalesRank': 575583,
#   'Copurchased': '',
#   'Categories': 'germani war europ book franc militari world ii western subject histori gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0781724716': {'Id': '1367',
#   'ASIN': '0781724716',
#   'Title': 'Child and Adolescent Clinical Psychopharmacology',
#   'Group': 'Book',
#   'SalesRank': 191671,
#   'Copurchased': '0521655420',
#   'Categories': 'medicin book pediatr bodi psycholog mind health subject counsel gener psychopharmacolog specialti',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0803949677': {'Id': '1368',
#   'ASIN': '0803949677',
#   'Title': 'The Power of Silence: Social and Pragmatic Perspectives (Language and Language Behavior)',
#   'Group': 'Book',
#   'SalesRank': 467756,
#   'Copurchased': '',
#   'Categories': 'nonfict scienc commun book refer word social subject languag gener sociolog',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0822525771': {'Id': '1369',
#   'ASIN': '0822525771',
#   'Title': "David's Story: A Book About Surgery (Meeting the Challenge)",
#   'Group': 'Book',
#   'SalesRank': 1848183,
#   'Copurchased': '',
#   'Categories': 'book subject age gener children',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0553214039': {'Id': '1370',
#   'ASIN': '0553214039',
#   'Title': 'The Swiss Family Robinson (Bantam Classics)',
#   'Group': 'Book',
#   'SalesRank': 1086094,
#   'Copurchased': '0451527046 0486404277',
#   'Categories': 'fiction classic book literatur genr action subject gener adventur',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0553298046': {'Id': '1371',
#   'ASIN': '0553298046',
#   'Title': 'Specter of the Past (Star Wars: The Hand of Thrawn, Book One)',
#   'Group': 'Book',
#   'SalesRank': 18558,
#   'Copurchased': '0553564927 0553296124',
#   'Categories': 'seri star fiction war book fantasi media subject gener scienc',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0471625469': {'Id': '1372',
#   'ASIN': '0471625469',
#   'Title': 'An Introduction to the Theory of Numbers',
#   'Group': 'Book',
#   'SalesRank': 263175,
#   'Copurchased': '0883856190 0198531710 038797329X',
#   'Categories': 'pure mathemat book theori technic number subject profession scienc',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0312063261': {'Id': '1373',
#   'ASIN': '0312063261',
#   'Title': "Dancing on Tisha B'av",
#   'Group': 'Book',
#   'SalesRank': 353629,
#   'Copurchased': '',
#   'Categories': 'fiction book gay literatur lesbian subject',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '8817125539': {'Id': '1374',
#   'ASIN': '8817125539',
#   'Title': 'An Italian in America',
#   'Group': 'Book',
#   'SalesRank': 238275,
#   'Copurchased': '',
#   'Categories': 'amazon com book memoir travel store categori subject biographi itali europ gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0531164659': {'Id': '1375',
#   'ASIN': '0531164659',
#   'Title': 'High School Hazing: When Rites Become Wrongs (Single Title: Teen)',
#   'Group': 'Book',
#   'SalesRank': 431993,
#   'Copurchased': '025321498X',
#   'Categories': 'peopl book teen bodi place social subject mind gener health scienc children',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1576751414': {'Id': '1376',
#   'ASIN': '1576751414',
#   'Title': 'Be Your Own Brand: A Breakthrough Formula for Standing Out from the Crowd',
#   'Group': 'Book',
#   'SalesRank': 141178,
#   'Copurchased': '0345423593 0967450616',
#   'Categories': 'amazon com advertis sale manag store counsel appli busi self success market offic transform home book leadership primer mind health person life bodi psycholog invest secret subject biographi help gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0619016884': {'Id': '1377',
#   'ASIN': '0619016884',
#   'Title': '70-220: MCSE Guide to Designing Microsoft Windows 2000 Security',
#   'Group': 'Book',
#   'SalesRank': 148463,
#   'Copurchased': '0619016892 078212898X',
#   'Categories': 'central amazon com internet manag mcse window store publish busi microsoft comput technolog project offic cours home comput digit book exam os cultur oper certif subject system gener secur',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0740725300': {'Id': '1378',
#   'ASIN': '0740725300',
#   'Title': 'Traveling Light 2003 Block Calendar: Releasing the Burdens You Were Never Intended to Bear; The',
#   'Group': 'Book',
#   'SalesRank': 745630,
#   'Copurchased': '',
#   'Categories': 'author z cultur religion note book accessori pop spiritu format max subject l lucado gener card',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0375503366': {'Id': '1379',
#   'ASIN': '0375503366',
#   'Title': 'The Requiem Shark : A Novel',
#   'Group': 'Book',
#   'SalesRank': 816290,
#   'Copurchased': '0805066152',
#   'Categories': 'contemporari fiction histor book literatur genr sea subject adventur gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0914732218': {'Id': '1380',
#   'ASIN': '0914732218',
#   'Title': 'AGHORA, At the Left Hand of God (Aghora)',
#   'Group': 'Book',
#   'SalesRank': 62274,
#   'Copurchased': '0914732315 0892540486 1883725046',
#   'Categories': 'occult religion book spiritu buddhism subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '9812348174': {'Id': '1381',
#   'ASIN': '9812348174',
#   'Title': 'Insight Compact Guide Ireland (Insight Compact Guides)',
#   'Group': 'Book',
#   'SalesRank': 1175363,
#   'Copurchased': '',
#   'Categories': 'seri europ amazon com book travel pocket insight subject ireland guidebook guid store gener categori',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0632057718': {'Id': '1382',
#   'ASIN': '0632057718',
#   'Title': "Architects' Data",
#   'Group': 'Book',
#   'SalesRank': 365164,
#   'Copurchased': '',
#   'Categories': 'book refer technic style architectur type build profession subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1876175087': {'Id': '1384',
#   'ASIN': '1876175087',
#   'Title': "Che in Africa: Che Guevara's Congo Diary",
#   'Group': 'Book',
#   'SalesRank': 836852,
#   'Copurchased': '',
#   'Categories': 'g academ histor z democrat polit congo che leader west caribbean america book cuba peopl republ guevara notabl profession militari memoir spi indi subject biographi histori gener africa',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1870775724': {'Id': '1388',
#   'ASIN': '1870775724',
#   'Title': 'Creating a Music Website',
#   'Group': 'Book',
#   'SalesRank': 1046034,
#   'Copurchased': '',
#   'Categories': 'midi web develop entertain comput book commerc etc site internet theori composit perform music subject design mixer gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0813521505': {'Id': '1389',
#   'ASIN': '0813521505',
#   'Title': "Irrationality: Why We Don't Think Straight!",
#   'Group': 'Book',
#   'SalesRank': 739364,
#   'Copurchased': '',
#   'Categories': 'scienc book behavior bodi psycholog mind health technic subject counsel profession gener scienc cognit',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '087840273X': {'Id': '1391',
#   'ASIN': '087840273X',
#   'Title': 'Alif Baa: Introduction to Arabic Letters and Sounds',
#   'Group': 'Book',
#   'SalesRank': 23006,
#   'Copurchased': '0879500034',
#   'Categories': 'arab book languag refer word foreign linguist instruct subject languag gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0395742129': {'Id': '1393',
#   'ASIN': '0395742129',
#   'Title': 'A Turkey for Thanksgiving',
#   'Group': 'Book',
#   'SalesRank': 273599,
#   'Copurchased': '0448422867',
#   'Categories': 'author peopl fiction z illustr book eve bunt place holiday b subject age festiv thanksgiv gener children',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0452284015': {'Id': '1394',
#   'ASIN': '0452284015',
#   'Title': 'The Darwin Awards II : Unnatural Selection',
#   'Group': 'Book',
#   'SalesRank': 26591,
#   'Copurchased': '',
#   'Categories': 'humor entertain book essay subject gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0743407083': {'Id': '1395',
#   'ASIN': '0743407083',
#   'Title': 'Grand Avenue',
#   'Group': 'Book',
#   'SalesRank': 177689,
#   'Copurchased': '0743407067 0451155068',
#   'Categories': 'contemporari author fiction z book field literatur f subject romanc joy gener',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0944386237': {'Id': '1396',
#   'ASIN': '0944386237',
#   'Title': 'The Bible Interpreted in Dream Symbols',
#   'Group': 'Book',
#   'SalesRank': 1598633,
#   'Copurchased': '',
#   'Categories': 'occult knowledg religi counsel dream studi spiritu mysteri mental book mind controversi health religion bodi psycholog subject gener unexplain',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1573801534': {'Id': '1397',
#   'ASIN': '1573801534',
#   'Title': "Insiders' Guide to Yellowstone and Grand Teton",
#   'Group': 'Book',
#   'SalesRank': 944279,
#   'Copurchased': '',
#   'Categories': 'seri amazon com categori store mountain unit region lodg wyom travel park west book campground yellowston guidebook food state subject gener insid',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '0520203569': {'Id': '1401',
#   'ASIN': '0520203569',
#   'Title': 'Early Modern Japan',
#   'Group': 'Book',
#   'SalesRank': 587569,
#   'Copurchased': '',
#   'Categories': 'book asia subject histori japan',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1878610473': {'Id': '1403',
#   'ASIN': '1878610473',
#   'Title': 'Working in the Dark: Reflections of a Poet of the Barrio',
#   'Group': 'Book',
#   'SalesRank': 484620,
#   'Copurchased': '0811211029',
#   'Categories': 'author book literatur memoir subject biographi gener art',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  '1864500069': {'Id': '1405',
#   'ASIN': '1864500069',
#   'Title': 'Loney Planet Chicago City Map (City Maps Series)',
#   'Group': 'Book',
#   'SalesRank': 554729,
#   'Copurchased': '',
#   'Categories': 'map amazon unit com book atlas illinoi refer state travel store categori chicago subject region midwest',
#   'TotalReviews': 0,
#   'AvgRating': 0.0},
#  ...}

# %% [markdown]
# ## Adding recommendation property

# %%
Copurchase_Graph = networkx.Graph() 
for asin, metadata in Amazon_Books.items():
    Copurchase_Graph.add_node(asin) 
    for a in metadata['Copurchased'].split():
        Copurchase_Graph.add_node(a.strip()) 
        similarity = 0 
        n1 = set((Amazon_Books[asin]['Categories']).split())
        n2 = set((Amazon_Books[a]['Categories']).split()) 
        n1In2 = n1 & n2           
        n1Un2 = n1 | n2
        if(len(n1In2)) > 0:
            similarity = round(len(n1In2) / len(n1Un2), 2) 
            Copurchase_Graph.add_edge(asin, a.strip(), weight = similarity)

# %%
dc = networkx.degree(Copurchase_Graph) 
for asin in networkx.nodes(Copurchase_Graph):
    metadata = Amazon_Books[asin] 
    metadata['DegreeCentrality'] = int(dc[asin]) 
    ego = networkx.ego_graph(Copurchase_Graph, asin, radius = 1) 
    metadata['ClusteringCoeff'] = round(networkx.average_clustering(ego), 2)
    Amazon_Books[asin] = metadata

# %%
Amazon_Books_File = open('amazon-books.txt', 'w', encoding = 'utf-8', errors = 'ignore')

Amazon_Books_File.write("Id\t" + "ASIN\t" + "Title\t" + "Categories\t" + "Group\t" + "Copurchased\t" + "SalesRank\t" + "TotalReviews\t" + "AvgRating\t" "DegreeCentrality\t" + 
                        "ClusteringCoeff\n") 

for asin, metadata in Amazon_Books.items(): # converting the meta-data into txt file
     Amazon_Books_File.write(metadata['Id'] + "\t" + \
                             asin + "\t" +  \
                             metadata['Title'] + "\t" + \
                             metadata['Categories'] + "\t" + \
                             metadata['Group'] + "\t" +  \
                             metadata['Copurchased'] + "\t" + \
                             str(metadata['SalesRank']) + "\t" + \
                             str(metadata['TotalReviews']) + "\t" + 
                             str(metadata['AvgRating']) + "\t" + \
                             str(metadata['DegreeCentrality']) + "\t" + \
                             str(metadata['ClusteringCoeff']) + "\n")

Amazon_Books_File.close()

# %%
# writing the adjacency edge list
Amazon_Books_File = open("amazon-books-copurchase.edgelist", 'wb') 
networkx.write_weighted_edgelist(Copurchase_Graph, Amazon_Books_File) 
Amazon_Books_File.close()

# %% [markdown]
# ## Reading the text file

# %%
Books_File = open('amazon-books.txt', 'r', encoding = 'utf-8', errors = 'ignore')
Books = {}
Books_File.readline()
for line in Books_File:
    cell = line.split("\t") 
    MetaData = {}
    MetaData['Id'] = cell[0].strip() 
    ASIN = cell[1].strip()
    MetaData['Title'] = cell[2].strip() 
    MetaData['Categories'] = cell[3].strip() 
    MetaData['Group'] = cell[4].strip() 
    MetaData['Copurchased'] = cell[5].strip()
    MetaData['SalesRank'] = int(cell[6].strip())
    MetaData['TotalReviews'] = int(cell[7].strip())
    MetaData['AvgRating'] = float(cell[8].strip())
    MetaData['DegreeCentrality'] = int(cell[9].strip())
    MetaData['ClusteringCoeff'] = float(cell[10].strip())
    Books[ASIN] = MetaData 
Books_File.close()

# %%
Books_File = open("amazon-books-copurchase.edgelist", "rb") 
Copurchase_Graph = networkx.read_weighted_edgelist(Books_File) 
Books_File.close()

# %% [markdown]
# ## Giving Book id as input for recommending books

# %%
print("Looking for Recommendations for Customer Purchasing this Book: ")
print("---------------------------------------------------------------")
Purchased_ASIN = '0843939338'
print("ASIN = ", Purchased_ASIN)
print("Title = ", Books[Purchased_ASIN]['Title'])
print("SalesRank = ", Books[Purchased_ASIN]['SalesRank'])
print("TotalReviews = ", Books[Purchased_ASIN]['TotalReviews'])
print("AvgRating = ", Books[Purchased_ASIN]['AvgRating'])
print("DegreeCentrality = ", Books[Purchased_ASIN]['DegreeCentrality'])
print("ClusteringCoeff = ", Books[Purchased_ASIN]['ClusteringCoeff'])
# Out:
# Looking for Recommendations for Customer Purchasing this Book:
# ---------------------------------------------------------------
# ASIN =  0843939338
# Title =  White Wind
# SalesRank =  43571
# TotalReviews =  0
# AvgRating =  0.0
# DegreeCentrality =  1
# ClusteringCoeff =  0.0

# %%
networkx.nodes(Copurchase_Graph)
# Out:
# NodeView(('0827229534', '0804215715', '0687023955', '0805415505', '0687179246', '0687173094', '0687336481', '0801021979', '082720230X', '0830815759', '0687045169', '0896225747', '1568540949', '0664258476', '0738700797', '1567184960', '0835608158', '1573929301', '0806524227', '080652247X', '0842328327', '0842328572', '0842328742', '0842328785', '0486220125', '0486401960', '0618138498', '0312117000', '0231118597', '080148605X', '0822217805', '0801487277', '0195110250', '0231118589', '0375709363', '0679730672', '0679739882', '0674009975', '0231073194', '0674003020', '0871318237', '0553577514', '0962741817', '1580540392', '0671010034', '0060184086', '1884820581', '0967271207', '0892817895', '0962741809', '0743237919', '0812991966', '0871318296', '1559362022', '1559360968', '1559361247', '0195110382', '1585741485', '0140246967', '0688149472', '0870211463', '1557508003', '0870211897', '0813338697', '1883809096', '0870210971', '1557500320', '0801868491', '0804100039', '0849311012', '1578200326', '3895780812', '0071343547', '0819444251', '0781712513', '0781736633', '0781729491', '0683301187', '1590930509', '0899193498', '0395288126', '0590411454', '0899194265', '0140563660', '0899197965', '0698113586', '0899192750', '0152863974', '0395899001', '0899190855', '0395287995', '0395181100', '0781718791', '0316467200', '0323019307', '0471150274', '1852331666', '0895872218', '1892514656', '0399145346', '0807844179', '0439240751', '0439240727', '0439240700', '0439240735', '0787950599', '014028852X', '0471163899', '0071401946', '0140157352', '0140235310', '0553371312', '0787953822', '0887308422', '0070393087', '0878408398', '0743526007', '0314228659', '0671634062', '0140296344', '0972488901', '0824807065', '0787965014', '0446676667', '1887078002', '019285433X', '0312199406', '0312267568', '0684853620', '0486268780', '0486275507', '0486401588', '0486272737', '0486285537', '0141180722', '0486268713', '0762405562', '0486292797', '0679418962', '0486295443', '0486278085', '0679735747', '0694520071', '0486270734', '0486401642', '0486408752', '0809288338', '0808510231', '0809288346', '1880323125', '0966580400', '1861007418', '1861006098', '1861006152', '186100737X', '1861006306', '1861007248', '0672321521', '1861005458', '1861007582', '1861006284', '0826449379', '0380651939', '0020435401', '002742510X', '0439420717', '0439284899', '0613100093', '0064401111', '0393971694', '039395272X', '039395191X', '0028730208', '0026879077', '0026879018', '1930288034', '0026878976', '0273651870', '0131000691', '053438367X', '0131031287', '0138574596', '0137463898', '0324116950', '0072424834', '0130180424', '0130341053', '0072334568', '0471238236', '0471283495', '157281196X', '1572812575', '1879181894', '0939680955', '1567185339', '0113300174', '9080671347', '0312982178', '0312277601', '0811726371', '0870216201', '1884997015', '1573227153', '0140430407', '0140186867', '0679732268', '0415157528', '0415224373', '0844283673', '0671727737', '0671746693', '0425138232', '1566913810', '0881504548', '1560445076', '037575380X', '0807009199', '0252068602', '1874509611', '0807009091', '068481580X', '0520212681', '039572774X', '0590381571', '067943464X', '0394544277', '1856263681', '0618129901', '0439254159', '0439187230', '0310485002', '1576832201', '0805454020', '0310236487', '0892839643', '0687132878', '0805460519', '0310243238', '0830730877', '0310237718', '042515517X', '0425176312', '0671725319', '0425182681', '0071402306', '006662097X', '0967498198', '0743509315', '0671023209', '0743453956', '0743527933', '0671047345', '0743506529', '0743436741', '0671047337', '1858685486', '0201135493', '1878347004', '0811828190', '0572019483', '1878347020', '1571458824', '185868546X', '0806997257', '1858685451', '080690187X', '0151803870', '015121185X', '0811201511', '089968291X', '0679642242', '0811201546', '0811203506', '0820451576', '1573928895', '0375726446', '0375726217', '0674053095', '0814788068', '0375504443', '1555919332', '0471366749', '0838531377', '0891283463', '0195129156',  ...

# %%
n = Purchased_ASIN
ego = networkx.ego_graph(Copurchase_Graph, n, radius = 1)
Purchased_ASIN_Ego_Graph = networkx.Graph(ego)

# %%
threshold = 0.5 # finding the nodes having similarity measure based on category above the threshold value
Purchased_ASIN_Ego_Trim_Graph = networkx.Graph()
for f, t, e in Purchased_ASIN_Ego_Graph.edges(data = True):
    if e['weight'] >= threshold: 
        Purchased_ASIN_Ego_Trim_Graph.add_edge(f, t)

# %%
Purchased_ASIN_Ego_Trim_Graph

# %%
Purchased_ASIN_Neighbors = Purchased_ASIN_Ego_Trim_Graph.neighbors(Purchased_ASIN)

# %%
ASIN_Meta = []
for asin in Purchased_ASIN_Neighbors:
    ASIN = asin
    Title = Amazon_Books[ASIN]['Title']
    SalesRank = Amazon_Books[ASIN]['SalesRank']
    TotalReviews = Amazon_Books[ASIN]['TotalReviews']
    AvgRating = Amazon_Books[ASIN]['AvgRating']
    DegreeCentrality = Amazon_Books[ASIN]['DegreeCentrality']
    ASIN_Meta.append((ASIN, Title, SalesRank, TotalReviews, AvgRating, DegreeCentrality, ClusteringCoeff))

# %%
Top5_ByAbgRating_ThenByTotalReviews = sorted(ASIN_Meta, key = lambda x: (x[4], x[3]), reverse = True)[:5]

# %%
print()
print("Top Recommendations By AvgRating Then By TotalReviews for Users Purchased The Book: ")
print("--------------------------------------------------------------------------------------")
print('ASIN\t', 'Title\t', 'SalesRank\t', 'TotalReviews\t', 'AvgRating\t', 'DegreeCentrality\t', 'ClusteringCoeff')
for asin in Top5_ByAbgRating_ThenByTotalReviews:
    print(asin)

print()
# Out:
# Top Recommendations By AvgRating Then By TotalReviews for Users Purchased The Book:
# --------------------------------------------------------------------------------------
# ASIN	 Title	 SalesRank	 TotalReviews	 AvgRating	 DegreeCentrality	 ClusteringCoeff
# ('0843947039', 'White Nights', 63959, 0, 0.0, 1, 0.0)
